# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanSwadhin/daily-python/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# GitHub raw link ব্যবহার করো
url = "https://raw.githubusercontent.com/RafsanSwadhin/daily-python/main/data/AirPassengers.csv"
trainingdata = pd.read_csv(url)
trainingdata.head(10)
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121
# 5  1949-06          135
# 6  1949-07          148
# 7  1949-08          148
# 8  1949-09          136
# 9  1949-10          119

# %%
plt.rcParams.update({'figure.figsize': (12, 6)})
trainingdata['#Passengers'].plot()
# Out:
# <Axes: >
